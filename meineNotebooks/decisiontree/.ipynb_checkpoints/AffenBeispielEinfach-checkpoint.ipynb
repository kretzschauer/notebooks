# %% [markdown]
# # Notebook für einen Entscheidungsbaum für Affen

# %% [markdown]
# Das Notebook arbeitet nur auf Listen, mit numpy wäre es sicher schneller.
#
# ToDo: Berechnen der Entropie.
#
# Daten einlesen und eine Liste erstellen.

# %%
datTrain="data/affen1trainingsdaten.csv"
datTest ="data/affen1testdaten.csv"


f=open(datTrain,"r", encoding="UTF-8")
txt=f.readlines()
affen=[]
for zei in txt[1:]:
    zei=zei.strip().split(";")
    affen.append(zei[0:])

label=txt[0].strip().split(";")[1:]
training_data = affen
header = label #die Bezeichnungen
affen, len(affen), label
# Out:
# ([['1', 'offen', 'offen', 'Zahn', 'keins', 'B'],
#   ['2', 'offen', 'zu', 'Zahn', 'keins', 'B'],
#   ['4', 'zu', 'zu', 'Zahn', 'keins', 'BN'],
#   ['5', 'offen', 'offen', 'Grinsen', 'keins', 'B'],
#   ['7', 'x', 'x', 'Grinsen', 'keins', 'BN'],
#   ['9', 'offen', 'offen', 'grimmig', 'keins', 'B'],
#   ['10', 'offen', 'zu', 'grimmig', 'keins', 'B'],
#   ['12', 'zu', 'zu', 'grimmig', 'keins', 'BN'],
#   ['14', 'offen', 'zu', 'weit offen', 'keins', 'B'],
#   ['15', 'x', 'x', 'weit offen', 'keins', 'B'],
#   ['16', 'zu', 'zu', 'weit offen', 'keins', 'B'],
#   ['17', 'offen', 'offen', 'Zunge', 'keins', 'B'],
#   ['19', 'x', 'x', 'Zunge', 'keins', 'BN'],
#   ['22', 'offen', 'zu', 'Zahn', 'Brille', 'BN'],
#   ['23', 'x', 'x', 'Zahn', 'Pflaster_links', 'BN'],
#   ['24', 'zu', 'zu', 'Zahn', 'keins', 'BN'],
#   ['25', 'offen', 'offen', 'Grinsen', 'Brille', 'BN'],
#   ['28', 'offen', 'offen', 'Grinsen', 'keins', 'B'],
#   ['30', 'offen', 'zu', 'grimmig', 'Haarschleife', 'BN'],
#   ['32', 'zu', 'zu', 'grimmig', 'Brille', 'BN'],
#   ['33', 'offen', 'offen', 'weit offen', 'Brille', 'B'],
#   ['35', 'x', 'x', 'weit offen', 'keins', 'B'],
#   ['36', 'zu', 'zu', 'weit offen', 'Haarschleife', 'B'],
#   ['37', 'offen', 'offen', 'Zunge', 'Augenbinde', 'BN'],
#   ['38', 'offen', 'zu', 'Zunge', 'Brille', 'BN'],
#   ['39', 'x', 'x', 'Zunge', 'Pflaster_links', 'BN'],
#   ['40', 'zu', 'zu', 'Zunge', 'keins', 'BN']],
#  27,
#  ['Auge_li', 'Auge_re', 'Mund', 'Ass', 'Beschriftung'])

# %%
f=open(datTest,"r", encoding="UTF-8")
txt=f.readlines()
affenTest=[]
for zei in txt[1:]:
    zei=zei.strip().split(";")
    affenTest.append(zei[1:])
affenTest
# Out:
# [['x', 'x', 'Zahn', 'keins', 'BN'],
#  ['offen', 'zu', 'Grinsen', 'keins', 'B'],
#  ['zu', 'zu', 'Grinsen', 'keins', 'BN'],
#  ['x', 'x', 'grimmig', 'keins', 'BN'],
#  ['offen', 'offen', 'weit offen', 'keins', 'B'],
#  ['offen', 'zu', 'Zunge', 'keins', 'B'],
#  ['offen', 'offen', 'verschmitzt', 'Augenbinde', 'BN'],
#  ['offen', 'zu', 'Grinsen', 'Pflaster_rechts', 'BN'],
#  ['x', 'x', 'Grinsen', 'Haare', 'BN'],
#  ['offen', 'offen', 'grimmig', 'Augenbinde', 'BN'],
#  ['x', 'x', 'grimmig', 'Pflaster_links', 'BN'],
#  ['offen', 'zu', 'offen', 'Pflaster_rechts', 'B']]

# %%
def unique_vals(rows, col):
    #erstellt eine Menge aus Merkmalen
    return set([row[col] for row in rows])

# %%
#######
# Demo:
#unique_vals(training_data, 0)
unique_vals(training_data, 3)
#######
# Out:
# {'Grinsen', 'Zahn', 'Zunge', 'grimmig', 'weit offen'}

# %%
def class_counts(rows):
    # zaehlt die verschiedenen Label
    counts = {}  # a dictionary of label -> count.
    for row in rows:
        # Label immer in der letzten Spalte
        label = row[-1]
        if label not in counts:
            counts[label] = 0
        counts[label] += 1
    return counts

# %%
#######
# Demo:
class_counts(training_data)
#######
# Out:
# {'B': 13, 'BN': 14}

# %%
def is_numeric(value):
    """Test if a value is numeric."""
    return isinstance(value, int) or isinstance(value, float)

# %%
#######
# Demo:
is_numeric(7)
# is_numeric("zu")
#######
# Out:
# True

# %%
class Question:
    """
    Danach werden die Daten geteilt
    Besteht aus Spalten-Namen und Wert
    match vergleicht einen Beispielwert mit dem der Frage
    """

    def __init__(self, column, value):
        self.column = column
        self.value = value

    def match(self, example):
        # Compare the feature value in an example to the
        # feature value in this question.
        val = example[self.column]
        if is_numeric(val):
            return val >= self.value
        else:
            return val == self.value

    def __repr__(self):
        # This is just a helper method to print
        # the question in a readable format.
        condition = "=="
        if is_numeric(self.value):
            condition = ">="
        return "Is %s %s %s?" % (
            header[self.column], condition, str(self.value))

# %%
#######
# Demo:
# Let's write a question for a numeric attribute
Question(1, 3)
# Out:
# Is Auge_re >= 3?

# %%
# How about one for a categorical attribute
q = Question(0, 'zu')
q
# Out:
# Is Auge_li == zu?

# %%
# Let's pick an example from the training set...
example = training_data[2]#Zeile 2 
# ... and see if it matches the question
q.match(example) # Vergleich der Spalte 0
#######
# Out:
# False

# %%
def partition(rows, question):
    """Partitions a dataset.

    For each row in the dataset, check if it matches the question. If
    so, add it to 'true rows', otherwise, add it to 'false rows'.
    """
    true_rows, false_rows = [], []
    for row in rows:
        if question.match(row):
            true_rows.append(row)
        else:
            false_rows.append(row)
    return true_rows, false_rows

# %%
#######
# Demo:
# Let's partition the training data based on whether rows are Red.
true_rows, false_rows = partition(training_data, Question(1, 'zu'))
# This will contain all the 'Red' rows.
true_rows
# Out:
# [['4', 'zu', 'zu', 'Zahn', 'keins', 'BN'],
#  ['12', 'zu', 'zu', 'grimmig', 'keins', 'BN'],
#  ['16', 'zu', 'zu', 'weit offen', 'keins', 'B'],
#  ['24', 'zu', 'zu', 'Zahn', 'keins', 'BN'],
#  ['32', 'zu', 'zu', 'grimmig', 'Brille', 'BN'],
#  ['36', 'zu', 'zu', 'weit offen', 'Haarschleife', 'B'],
#  ['40', 'zu', 'zu', 'Zunge', 'keins', 'BN']]

# %%
# This will contain everything else.
false_rows
#######
# Out:
# [['1', 'offen', 'offen', 'Zahn', 'keins', 'B'],
#  ['2', 'offen', 'zu', 'Zahn', 'keins', 'B'],
#  ['5', 'offen', 'offen', 'Grinsen', 'keins', 'B'],
#  ['7', 'x', 'x', 'Grinsen', 'keins', 'BN'],
#  ['9', 'offen', 'offen', 'grimmig', 'keins', 'B'],
#  ['10', 'offen', 'zu', 'grimmig', 'keins', 'B'],
#  ['14', 'offen', 'zu', 'weit offen', 'keins', 'B'],
#  ['15', 'x', 'x', 'weit offen', 'keins', 'B'],
#  ['17', 'offen', 'offen', 'Zunge', 'keins', 'B'],
#  ['19', 'x', 'x', 'Zunge', 'keins', 'BN'],
#  ['22', 'offen', 'zu', 'Zahn', 'Brille', 'BN'],
#  ['23', 'x', 'x', 'Zahn', 'Pflaster_links', 'BN'],
#  ['25', 'offen', 'offen', 'Grinsen', 'Brille', 'BN'],
#  ['28', 'offen', 'offen', 'Grinsen', 'keins', 'B'],
#  ['30', 'offen', 'zu', 'grimmig', 'Haarschleife', 'BN'],
#  ['33', 'offen', 'offen', 'weit offen', 'Brille', 'B'],
#  ['35', 'x', 'x', 'weit offen', 'keins', 'B'],
#  ['37', 'offen', 'offen', 'Zunge', 'Augenbinde', 'BN'],
#  ['38', 'offen', 'zu', 'Zunge', 'Brille', 'BN'],
#  ['39', 'x', 'x', 'Zunge', 'Pflaster_links', 'BN']]

# %%
def gini(rows):
    """
    Gini Index für eine Liste aus Zeilen
    There are a few different ways to do this, I thought this one was
    the most concise. See:
    https://en.wikipedia.org/wiki/Decision_tree_learning#Gini_impurity
    """
    counts = class_counts(rows)
    print(counts)
    impurity = 1
    for lbl in counts:
        print(lbl)
        prob_of_lbl = counts[lbl] / float(len(rows))
        print(lbl,prob_of_lbl,prob_of_lbl**2)
        impurity -= prob_of_lbl**2
    return impurity

# %%
#######
# Demo:
# Let's look at some example to understand how Gini Impurity works.
#
# First, we'll look at a dataset with no mixing.
no_mixing = [['auf'],
              ['auf']]
# this will return 0
#gini(no_mixing)
gini(false_rows)
# Out:
# {'B': 11, 'BN': 9}
# B
# B 0.55 0.30250000000000005
# BN
# BN 0.45 0.2025
# 0.495

# %%
# Now, we'll look at dataset with a 50:50 apples:oranges ratio
some_mixing = [['auf'],
               ['zu']]
# this will return 0.5 - meaning, there's a 50% chance of misclassifying
# a random example we draw from the dataset.
gini(some_mixing)
# Out:
# {'auf': 1, 'zu': 1}
# auf
# auf 0.5 0.25
# zu
# zu 0.5 0.25
# 0.5

# %%
# Now, we'll look at a dataset with many different labels
lots_of_mixing = [['c'],['c'],['c'],['c'],['x'],['x'],['x']]
                  
# This will return 0.64
gini(lots_of_mixing)
#######
# Out:
# {'c': 4, 'x': 3}
# c
# c 0.5714285714285714 0.32653061224489793
# x
# x 0.42857142857142855 0.18367346938775508
# 0.48979591836734704

# %%
def info_gain(left, right, current_uncertainty):
    """Information Gain.
    Die Unsicherheit des Startknotens, minus die gewichtete Unreinheit der beiden Kindknoten
    """
    p = float(len(left)) / (len(left) + len(right))
    print ("p:",p,len(left))
    return current_uncertainty - p * gini(left) - (1 - p) * gini(right)

# %%
def entropie(rows):
    counts = class_counts(rows)
    print(counts)
    entropy=0
    """    
      value,counts = np.unique(labels, return_counts=True)
      norm_counts = counts / counts.sum()
      return -(norm_counts * np.log(norm_counts)/np.log(2)).sum()
    """
    for lbl in counts:
        print(lbl)
        prob_of_lbl = counts[lbl] / float(len(rows))
        print(lbl,prob_of_lbl,prob_of_lbl**2)
        entropie -= prob_of_lbl*np.log(prob_of_lbl)/np.log(2)
    return entropy

# %%
#######
# Demo:
# Calculate the uncertainy of our training data.
current_uncertainty = gini(training_data)
training_data,current_uncertainty
# Out:
# {'B': 13, 'BN': 14}
# B
# B 0.48148148148148145 0.23182441700960216
# BN
# BN 0.5185185185185185 0.2688614540466392
# ([['1', 'offen', 'offen', 'Zahn', 'keins', 'B'],
#   ['2', 'offen', 'zu', 'Zahn', 'keins', 'B'],
#   ['4', 'zu', 'zu', 'Zahn', 'keins', 'BN'],
#   ['5', 'offen', 'offen', 'Grinsen', 'keins', 'B'],
#   ['7', 'x', 'x', 'Grinsen', 'keins', 'BN'],
#   ['9', 'offen', 'offen', 'grimmig', 'keins', 'B'],
#   ['10', 'offen', 'zu', 'grimmig', 'keins', 'B'],
#   ['12', 'zu', 'zu', 'grimmig', 'keins', 'BN'],
#   ['14', 'offen', 'zu', 'weit offen', 'keins', 'B'],
#   ['15', 'x', 'x', 'weit offen', 'keins', 'B'],
#   ['16', 'zu', 'zu', 'weit offen', 'keins', 'B'],
#   ['17', 'offen', 'offen', 'Zunge', 'keins', 'B'],
#   ['19', 'x', 'x', 'Zunge', 'keins', 'BN'],
#   ['22', 'offen', 'zu', 'Zahn', 'Brille', 'BN'],
#   ['23', 'x', 'x', 'Zahn', 'Pflaster_links', 'BN'],
#   ['24', 'zu', 'zu', 'Zahn', 'keins', 'BN'],
#   ['25', 'offen', 'offen', 'Grinsen', 'Brille', 'BN'],
#   ['28', 'offen', 'offen', 'Grinsen', 'keins', 'B'],
#   ['30', 'offen', 'zu', 'grimmig', 'Haarschleife', 'BN'],
#   ['32', 'zu', 'zu', 'grimmig', 'Brille', 'BN'],
#   ['33', 'offen', 'offen', 'weit offen', 'Brille', 'B'],
#   ['35', 'x', 'x', 'weit offen', 'keins', 'B'],
#   ['36', 'zu', 'zu', 'weit offen', 'Haarschleife', 'B'],
#   ['37', 'offen', 'offen', 'Zunge', 'Augenbinde', 'BN'],
#   ['38', 'offen', 'zu', 'Zunge', 'Brille', 'BN'],
#   ['39', 'x', 'x', 'Zunge', 'Pflaster_links', 'BN'],
#   ['40', 'zu', 'zu', 'Zunge', 'keins', 'BN']],
#  0.4993141289437586)

# %%
# How much information do we gain by partioning on 'offen'?
true_rows, false_rows = partition(training_data, Question(3, '1'))
info_gain(true_rows, false_rows, current_uncertainty)
# Out:
# p: 0.0 0
# {}
# {'B': 13, 'BN': 14}
# B
# B 0.48148148148148145 0.23182441700960216
# BN
# BN 0.5185185185185185 0.2688614540466392
# 0.0

# %%
true_rows, false_rows = partition(training_data, Question(2, '1'))
info_gain(true_rows, false_rows, current_uncertainty),current_uncertainty
# Out:
# p: 0.0 0
# {}
# {'B': 13, 'BN': 14}
# B
# B 0.48148148148148145 0.23182441700960216
# BN
# BN 0.5185185185185185 0.2688614540466392
# (0.0, 0.4993141289437586)

# %%
# What about if we partioned on 'Red' instead?
true_rows, false_rows = partition(training_data, Question(0,'1'))
info_gain(true_rows, false_rows, current_uncertainty),current_uncertainty
# Out:
# p: 0.037037037037037035 1
# {'B': 1}
# B
# B 1.0 1.0
# {'B': 12, 'BN': 14}
# B
# B 0.46153846153846156 0.21301775147928997
# BN
# BN 0.5384615384615384 0.28994082840236685
# (0.020681650311279887, 0.4993141289437586)

# %%
# It looks like we learned more using 'Red' (0.37), than 'Green' (0.14).
# Why? Look at the different splits that result, and see which one
# looks more 'unmixed' to you.
true_rows, false_rows = partition(training_data, Question(0,'auf'))

# Here, the true_rows contain only 'Grapes'.
true_rows
# Out:
# []

# %%
# And the false rows contain two types of fruit. Not too bad.
false_rows
# Out:
# [['1', 'offen', 'offen', 'Zahn', 'keins', 'B'],
#  ['2', 'offen', 'zu', 'Zahn', 'keins', 'B'],
#  ['4', 'zu', 'zu', 'Zahn', 'keins', 'BN'],
#  ['5', 'offen', 'offen', 'Grinsen', 'keins', 'B'],
#  ['7', 'x', 'x', 'Grinsen', 'keins', 'BN'],
#  ['9', 'offen', 'offen', 'grimmig', 'keins', 'B'],
#  ['10', 'offen', 'zu', 'grimmig', 'keins', 'B'],
#  ['12', 'zu', 'zu', 'grimmig', 'keins', 'BN'],
#  ['14', 'offen', 'zu', 'weit offen', 'keins', 'B'],
#  ['15', 'x', 'x', 'weit offen', 'keins', 'B'],
#  ['16', 'zu', 'zu', 'weit offen', 'keins', 'B'],
#  ['17', 'offen', 'offen', 'Zunge', 'keins', 'B'],
#  ['19', 'x', 'x', 'Zunge', 'keins', 'BN'],
#  ['22', 'offen', 'zu', 'Zahn', 'Brille', 'BN'],
#  ['23', 'x', 'x', 'Zahn', 'Pflaster_links', 'BN'],
#  ['24', 'zu', 'zu', 'Zahn', 'keins', 'BN'],
#  ['25', 'offen', 'offen', 'Grinsen', 'Brille', 'BN'],
#  ['28', 'offen', 'offen', 'Grinsen', 'keins', 'B'],
#  ['30', 'offen', 'zu', 'grimmig', 'Haarschleife', 'BN'],
#  ['32', 'zu', 'zu', 'grimmig', 'Brille', 'BN'],
#  ['33', 'offen', 'offen', 'weit offen', 'Brille', 'B'],
#  ['35', 'x', 'x', 'weit offen', 'keins', 'B'],
#  ['36', 'zu', 'zu', 'weit offen', 'Haarschleife', 'B'],
#  ['37', 'offen', 'offen', 'Zunge', 'Augenbinde', 'BN'],
#  ['38', 'offen', 'zu', 'Zunge', 'Brille', 'BN'],
#  ['39', 'x', 'x', 'Zunge', 'Pflaster_links', 'BN'],
#  ['40', 'zu', 'zu', 'Zunge', 'keins', 'BN']]

# %%
# On the other hand, partitioning by Green doesn't help so much.
true_rows, false_rows = partition(training_data, Question(0,'auf'))

# We've isolated one apple in the true rows.
true_rows
# Out:
# []

# %%
# But, the false-rows are badly mixed up.
false_rows
#######
# Out:
# [['1', 'offen', 'offen', 'Zahn', 'keins', 'B'],
#  ['2', 'offen', 'zu', 'Zahn', 'keins', 'B'],
#  ['4', 'zu', 'zu', 'Zahn', 'keins', 'BN'],
#  ['5', 'offen', 'offen', 'Grinsen', 'keins', 'B'],
#  ['7', 'x', 'x', 'Grinsen', 'keins', 'BN'],
#  ['9', 'offen', 'offen', 'grimmig', 'keins', 'B'],
#  ['10', 'offen', 'zu', 'grimmig', 'keins', 'B'],
#  ['12', 'zu', 'zu', 'grimmig', 'keins', 'BN'],
#  ['14', 'offen', 'zu', 'weit offen', 'keins', 'B'],
#  ['15', 'x', 'x', 'weit offen', 'keins', 'B'],
#  ['16', 'zu', 'zu', 'weit offen', 'keins', 'B'],
#  ['17', 'offen', 'offen', 'Zunge', 'keins', 'B'],
#  ['19', 'x', 'x', 'Zunge', 'keins', 'BN'],
#  ['22', 'offen', 'zu', 'Zahn', 'Brille', 'BN'],
#  ['23', 'x', 'x', 'Zahn', 'Pflaster_links', 'BN'],
#  ['24', 'zu', 'zu', 'Zahn', 'keins', 'BN'],
#  ['25', 'offen', 'offen', 'Grinsen', 'Brille', 'BN'],
#  ['28', 'offen', 'offen', 'Grinsen', 'keins', 'B'],
#  ['30', 'offen', 'zu', 'grimmig', 'Haarschleife', 'BN'],
#  ['32', 'zu', 'zu', 'grimmig', 'Brille', 'BN'],
#  ['33', 'offen', 'offen', 'weit offen', 'Brille', 'B'],
#  ['35', 'x', 'x', 'weit offen', 'keins', 'B'],
#  ['36', 'zu', 'zu', 'weit offen', 'Haarschleife', 'B'],
#  ['37', 'offen', 'offen', 'Zunge', 'Augenbinde', 'BN'],
#  ['38', 'offen', 'zu', 'Zunge', 'Brille', 'BN'],
#  ['39', 'x', 'x', 'Zunge', 'Pflaster_links', 'BN'],
#  ['40', 'zu', 'zu', 'Zunge', 'keins', 'BN']]

# %%
def find_best_split(rows):
    """Find the best question to ask by iterating over every feature / value
    and calculating the information gain."""
    best_gain = 0  # keep track of the best information gain
    best_question = None  # keep train of the feature / value that produced it
    current_uncertainty = gini(rows)
    n_features = len(rows[0]) - 1  # number of columns

    for col in range(n_features):  # for each feature

        values = set([row[col] for row in rows])  # unique values in the column

        for val in values:  # for each value

            question = Question(col, val)

            # try splitting the dataset
            true_rows, false_rows = partition(rows, question)

            # Skip this split if it doesn't divide the
            # dataset.
            if len(true_rows) == 0 or len(false_rows) == 0:
                continue

            # Calculate the information gain from this split
            gain = info_gain(true_rows, false_rows, current_uncertainty)

            # You actually can use '>' instead of '>=' here
            # but I wanted the tree to look a certain way for our
            # toy dataset.
            if gain >= best_gain:
                best_gain, best_question = gain, question
                print(best_gain, best_question)

    return best_gain, best_question

# %%
#######
# Demo:
# Find the best question to ask first for our toy dataset.
best_gain, best_question = find_best_split(training_data)
best_question
# FYI: is color == Red is just as good. See the note in the code above
# where I used '>='.
#######
# Out:
# {'B': 13, 'BN': 14}
# B
# B 0.48148148148148145 0.23182441700960216
# BN
# BN 0.5185185185185185 0.2688614540466392
# p: 0.037037037037037035 1
# {'BN': 1}
# BN
# BN 1.0 1.0
# {'B': 13, 'BN': 13}
# B
# B 0.5 0.25
# BN
# BN 0.5 0.25
# 0.017832647462277085 Is Auge_li == 12?
# p: 0.037037037037037035 1
# {'BN': 1}
# BN
# BN 1.0 1.0
# {'B': 13, 'BN': 13}
# B
# B 0.5 0.25
# BN
# BN 0.5 0.25
# 0.017832647462277085 Is Auge_li == 25?
# p: 0.037037037037037035 1
# {'B': 1}
# B
# B 1.0 1.0
# {'B': 12, 'BN': 14}
# B
# B 0.46153846153846156 0.21301775147928997
# BN
# BN 0.5384615384615384 0.28994082840236685
# 0.020681650311279887 Is Auge_li == 9?
# p: 0.037037037037037035 1
# {'B': 1}
# B
# B 1.0 1.0
# {'B': 12, 'BN': 14}
# B
# B 0.46153846153846156 0.21301775147928997
# BN
# BN 0.5384615384615384 0.28994082840236685
# 0.020681650311279887 Is Auge_li == 33?
# p: 0.037037037037037035 1
# {'BN': 1}
# BN
# BN 1.0 1.0
# {'B': 13, 'BN': 13}
# B
# B 0.5 0.25
# BN
# BN 0.5 0.25
# p: 0.037037037037037035 1
# {'BN': 1}
# BN
# BN 1.0 1.0
# {'B': 13, 'BN': 13}
# B
# B 0.5 0.25
# BN
# BN 0.5 0.25
# p: 0.037037037037037035 1
# {'B': 1}
# B
# B 1.0 1.0
# {'B': 12, 'BN': 14}
# B
# B 0.46153846153846156 0.21301775147928997
# BN
# BN 0.5384615384615384 0.28994082840236685
# 0.020681650311279887 Is Auge_li == 1?
# p: 0.037037037037037035 1
# {'B': 1}
# B
# B 1.0 1.0
# {'B': 12, 'BN': 14}
# B
# B 0.46153846153846156 0.21301775147928997
# BN
# BN 0.5384615384615384 0.28994082840236685
# 0.020681650311279887 Is Auge_li == 10?
# p: 0.037037037037037035 1
# {'B': 1}
# B
# B 1.0 1.0
# {'B': 12, 'BN': 14}
# B
# B 0.46153846153846156 0.21301775147928997
# BN
# BN 0.5384615384615384 0.28994082840236685
# 0.020681650311279887 Is Auge_li == 17?
# p: 0.037037037037037035 1
# {'BN': 1}
# BN
# BN 1.0 1.0
# {'B': 13, 'BN': 13}
# B
# B 0.5 0.25
# BN
# BN 0.5 0.25
# p: 0.037037037037037035 1
# {'B': 1}
# B
# B 1.0 1.0
# {'B': 12, 'BN': 14}
# B
# B 0.46153846153846156 0.21301775147928997
# BN
# BN 0.5384615384615384 0.28994082840236685
# 0.020681650311279887 Is Auge_li == 35?
# p: 0.037037037037037035 1
# {'B': 1}
# B
# B 1.0 1.0
# {'B': 12, 'BN': 14}
# B
# B 0.46153846153846156 0.21301775147928997
# BN
# BN 0.5384615384615384 0.28994082840236685
# 0.020681650311279887 Is Auge_li == 28?
# p: 0.037037037037037035 1
# {'BN': 1}
# BN
# BN 1.0 1.0
# {'B': 13, 'BN': 13}
# B
# B 0.5 0.25
# BN
# BN 0.5 0.25
# p: 0.037037037037037035 1
# {'BN': 1}
# BN
# BN 1.0 1.0
# {'B': 13, 'BN': 13}
# B
# B 0.5 0.25
# BN
# BN 0.5 0.25
# p: 0.037037037037037035 1
# {'BN': 1}
# BN
# BN 1.0 1.0
# {'B': 13, 'BN': 13}
# B
# B 0.5 0.25
# BN
# BN 0.5 0.25
# p: 0.037037037037037035 1
# {'B': 1}
# B
# B 1.0 1.0
# {'B': 12, 'BN': 14}
# B
# B 0.46153846153846156 0.21301775147928997
# BN
# BN 0.5384615384615384 0.28994082840236685
# 0.020681650311279887 Is Auge_li == 16?
# p: 0.037037037037037035 1
# {'BN': 1}
# BN
# BN 1.0 1.0
# {'B': 13, 'BN': 13}
# B
# B 0.5 0.25
# BN
# BN 0.5 0.25
# p: 0.037037037037037035 1
# {'B': 1}
# B
# B 1.0 1.0
# {'B': 12, 'BN': 14}
# B
# B 0.46153846153846156 0.21301775147928997
# BN
# BN 0.5384615384615384 0.28994082840236685
# 0.020681650311279887 Is Auge_li == 5?
# p: 0.037037037037037035 1
# {'BN': 1}
# BN
# BN 1.0 1.0
# {'B': 13, 'BN': 13}
# B
# B 0.5 0.25
# BN
# BN 0.5 0.25
# p: 0.037037037037037035 1
# {'BN': 1}
# BN
# BN 1.0 1.0
# {'B': 13, 'BN': 13}
# B
# B 0.5 0.25
# BN
# BN 0.5 0.25
# p: 0.037037037037037035 1
# {'BN': 1}
# BN
# BN 1.0 1.0
# {'B': 13, 'BN': 13}
# B
# B 0.5 0.25
# BN
# BN 0.5 0.25
# p: 0.037037037037037035 1
# {'BN': 1}
# BN
# BN 1.0 1.0
# {'B': 13, 'BN': 13}
# B
# B 0.5 0.25
# BN
# BN 0.5 0.25
# p: 0.037037037037037035 1
# {'B': 1}
# B
# B 1.0 1.0
# {'B': 12, 'BN': 14}
# B
# B 0.46153846153846156 0.21301775147928997
# BN
# BN 0.5384615384615384 0.28994082840236685
# 0.020681650311279887 Is Auge_li == 14?
# p: 0.037037037037037035 1
# {'BN': 1}
# BN
# BN 1.0 1.0
# {'B': 13, 'BN': 13}
# B
# B 0.5 0.25
# BN
# BN 0.5 0.25
# p: 0.037037037037037035 1
# {'B': 1}
# B
# B 1.0 1.0
# {'B': 12, 'BN': 14}
# B
# B 0.46153846153846156 0.21301775147928997
# BN
# BN 0.5384615384615384 0.28994082840236685
# 0.020681650311279887 Is Auge_li == 15?
# p: 0.037037037037037035 1
# {'B': 1}
# B
# B 1.0 1.0
# {'B': 12, 'BN': 14}
# B
# B 0.46153846153846156 0.21301775147928997
# BN
# BN 0.5384615384615384 0.28994082840236685
# 0.020681650311279887 Is Auge_li == 36?
# p: 0.037037037037037035 1
# {'B': 1}
# B
# B 1.0 1.0
# {'B': 12, 'BN': 14}
# B
# B 0.46153846153846156 0.21301775147928997
# BN
# BN 0.5384615384615384 0.28994082840236685
# 0.020681650311279887 Is Auge_li == 2?
# p: 0.2222222222222222 6
# {'BN': 4, 'B': 2}
# BN
# BN 0.6666666666666666 0.4444444444444444
# B
# B 0.3333333333333333 0.1111111111111111
# {'B': 11, 'BN': 10}
# B
# B 0.5238095238095238 0.2743764172335601
# BN
# BN 0.47619047619047616 0.22675736961451246
# p: 0.25925925925925924 7
# {'BN': 5, 'B': 2}
# BN
# BN 0.7142857142857143 0.5102040816326531
# B
# B 0.2857142857142857 0.08163265306122448
# {'B': 11, 'BN': 9}
# B
# B 0.55 0.30250000000000005
# BN
# BN 0.45 0.2025
# 0.02682735645698614 Is Auge_re == zu?
# p: 0.5185185185185185 14
# {'B': 9, 'BN': 5}
# B
# B 0.6428571428571429 0.41326530612244905
# BN
# BN 0.35714285714285715 0.12755102040816327
# {'BN': 9, 'B': 4}
# BN
# BN 0.6923076923076923 0.4792899408284023
# B
# B 0.3076923076923077 0.09467455621301776
# 0.05609068572031545 Is Auge_re == offen?
# p: 0.2222222222222222 6
# {'BN': 4, 'B': 2}
# BN
# BN 0.6666666666666666 0.4444444444444444
# B
# B 0.3333333333333333 0.1111111111111111
# {'B': 11, 'BN': 10}
# B
# B 0.5238095238095238 0.2743764172335601
# BN
# BN 0.47619047619047616 0.22675736961451246
# p: 0.48148148148148145 13
# {'B': 5, 'BN': 8}
# B
# B 0.38461538461538464 0.14792899408284024
# BN
# BN 0.6153846153846154 0.37869822485207105
# {'B': 8, 'BN': 6}
# B
# B 0.5714285714285714 0.32653061224489793
# BN
# BN 0.42857142857142855 0.18367346938775508
# p: 0.2962962962962963 8
# {'B': 6, 'BN': 2}
# B
# B 0.75 0.5625
# BN
# BN 0.25 0.0625
# {'B': 7, 'BN': 12}
# B
# B 0.3684210526315789 0.13573407202216065
# BN
# BN 0.631578947368421 0.39889196675900274
# 0.060717637715688444 Is Mund == offen?
# p: 0.2222222222222222 6
# {'B': 1, 'BN': 5}
# B
# B 0.16666666666666666 0.027777777777777776
# BN
# BN 0.8333333333333334 0.6944444444444445
# {'B': 12, 'BN': 9}
# B
# B 0.5714285714285714 0.32653061224489793
# BN
# BN 0.42857142857142855 0.18367346938775508
# p: 0.2222222222222222 6
# {'B': 2, 'BN': 4}
# B
# B 0.3333333333333333 0.1111111111111111
# BN
# BN 0.6666666666666666 0.4444444444444444
# {'B': 11, 'BN': 10}
# B
# B 0.5238095238095238 0.2743764172335601
# BN
# BN 0.47619047619047616 0.22675736961451246
# p: 0.18518518518518517 5
# {'B': 2, 'BN': 3}
# B
# B 0.4 0.16000000000000003
# BN
# BN 0.6 0.36
# {'B': 11, 'BN': 11}
# B
# B 0.5 0.25
# BN
# BN 0.5 0.25
# p: 0.14814814814814814 4
# {'B': 2, 'BN': 2}
# B
# B 0.5 0.25
# BN
# BN 0.5 0.25
# {'B': 11, 'BN': 12}
# B
# B 0.4782608695652174 0.2287334593572779
# BN
# BN 0.5217391304347826 0.2722117202268431
# p: 0.2222222222222222 6
# {'B': 6}
# B
# B 1.0 1.0
# {'B': 7, 'BN': 14}
# B
# B 0.3333333333333333 0.1111111111111111
# BN
# BN 0.6666666666666666 0.4444444444444444
# 0.1536351165980796 Is Ass == weit offen?
# p: 0.07407407407407407 2
# {'BN': 1, 'B': 1}
# BN
# BN 0.5 0.25
# B
# B 0.5 0.25
# {'B': 12, 'BN': 13}
# B
# B 0.48 0.2304
# BN
# BN 0.52 0.27040000000000003
# p: 0.6296296296296297 17
# {'B': 11, 'BN': 6}
# B
# B 0.6470588235294118 0.41868512110726647
# BN
# BN 0.35294117647058826 0.12456747404844293
# {'BN': 8, 'B': 2}
# BN
# BN 0.8 0.6400000000000001
# B
# B 0.2 0.04000000000000001
# p: 0.07407407407407407 2
# {'BN': 2}
# BN
# BN 1.0 1.0
# {'B': 13, 'BN': 12}
# B
# B 0.52 0.27040000000000003
# BN
# BN 0.48 0.2304
# p: 0.18518518518518517 5
# {'BN': 4, 'B': 1}
# BN
# BN 0.8 0.6400000000000001
# B
# B 0.2 0.04000000000000001
# {'B': 12, 'BN': 10}
# B
# B 0.5454545454545454 0.29752066115702475
# BN
# BN 0.45454545454545453 0.20661157024793386
# p: 0.037037037037037035 1
# {'BN': 1}
# BN
# BN 1.0 1.0
# {'B': 13, 'BN': 13}
# B
# B 0.5 0.25
# BN
# BN 0.5 0.25
# Is Ass == weit offen?

# %%
class Leaf:
    """A Leaf node classifies data.

    This holds a dictionary of class (e.g., "Apple") -> number of times
    it appears in the rows from the training data that reach this leaf.
    """

    def __init__(self, rows):
        self.predictions = class_counts(rows)

# %%
class Decision_Node:
    """A Decision Node asks a question.

    This holds a reference to the question, and to the two child nodes.
    """

    def __init__(self,
                 question,
                 true_branch,
                 false_branch):
        self.question = question
        self.true_branch = true_branch
        self.false_branch = false_branch

# %%
def build_tree(rows):
    """Builds the tree.

    Rules of recursion: 1) Believe that it works. 2) Start by checking
    for the base case (no further information gain). 3) Prepare for
    giant stack traces.
    """

    # Try partitioing the dataset on each of the unique attribute,
    # calculate the information gain,
    # and return the question that produces the highest gain.
    gain, question = find_best_split(rows)

    # Base case: no further info gain
    # Since we can ask no further questions,
    # we'll return a leaf.
    if gain == 0:
        return Leaf(rows)

    # If we reach here, we have found a useful feature / value
    # to partition on.
    true_rows, false_rows = partition(rows, question)

    # Recursively build the true branch.
    true_branch = build_tree(true_rows)

    # Recursively build the false branch.
    false_branch = build_tree(false_rows)

    # Return a Question node.
    # This records the best feature / value to ask at this point,
    # as well as the branches to follow
    # dependingo on the answer.
    return Decision_Node(question, true_branch, false_branch)

# %%
def print_tree(node, spacing=""):
    """World's most elegant tree printing function."""

    # Base case: we've reached a leaf
    if isinstance(node, Leaf):
        print (spacing + "Predict", node.predictions)
        return

    # Print the question at this node
    print (spacing + str(node.question))

    # Call this function recursively on the true branch
    print (spacing + '--> True:')
    print_tree(node.true_branch, spacing + "  ")

    # Call this function recursively on the false branch
    print (spacing + '--> False:')
    print_tree(node.false_branch, spacing + "  ")

# %%
my_tree = build_tree(training_data)
# Out:
# {'B': 13, 'BN': 14}
# B
# B 0.48148148148148145 0.23182441700960216
# BN
# BN 0.5185185185185185 0.2688614540466392
# p: 0.037037037037037035 1
# {'BN': 1}
# BN
# BN 1.0 1.0
# {'B': 13, 'BN': 13}
# B
# B 0.5 0.25
# BN
# BN 0.5 0.25
# 0.017832647462277085 Is Auge_li == 12?
# p: 0.037037037037037035 1
# {'BN': 1}
# BN
# BN 1.0 1.0
# {'B': 13, 'BN': 13}
# B
# B 0.5 0.25
# BN
# BN 0.5 0.25
# 0.017832647462277085 Is Auge_li == 25?
# p: 0.037037037037037035 1
# {'B': 1}
# B
# B 1.0 1.0
# {'B': 12, 'BN': 14}
# B
# B 0.46153846153846156 0.21301775147928997
# BN
# BN 0.5384615384615384 0.28994082840236685
# 0.020681650311279887 Is Auge_li == 9?
# p: 0.037037037037037035 1
# {'B': 1}
# B
# B 1.0 1.0
# {'B': 12, 'BN': 14}
# B
# B 0.46153846153846156 0.21301775147928997
# BN
# BN 0.5384615384615384 0.28994082840236685
# 0.020681650311279887 Is Auge_li == 33?
# p: 0.037037037037037035 1
# {'BN': 1}
# BN
# BN 1.0 1.0
# {'B': 13, 'BN': 13}
# B
# B 0.5 0.25
# BN
# BN 0.5 0.25
# p: 0.037037037037037035 1
# {'BN': 1}
# BN
# BN 1.0 1.0
# {'B': 13, 'BN': 13}
# B
# B 0.5 0.25
# BN
# BN 0.5 0.25
# p: 0.037037037037037035 1
# {'B': 1}
# B
# B 1.0 1.0
# {'B': 12, 'BN': 14}
# B
# B 0.46153846153846156 0.21301775147928997
# BN
# BN 0.5384615384615384 0.28994082840236685
# 0.020681650311279887 Is Auge_li == 1?
# p: 0.037037037037037035 1
# {'B': 1}
# B
# B 1.0 1.0
# {'B': 12, 'BN': 14}
# B
# B 0.46153846153846156 0.21301775147928997
# BN
# BN 0.5384615384615384 0.28994082840236685
# 0.020681650311279887 Is Auge_li == 10?
# p: 0.037037037037037035 1
# {'B': 1}
# B
# B 1.0 1.0
# {'B': 12, 'BN': 14}
# B
# B 0.46153846153846156 0.21301775147928997
# BN
# BN 0.5384615384615384 0.28994082840236685
# 0.020681650311279887 Is Auge_li == 17?
# p: 0.037037037037037035 1
# {'BN': 1}
# BN
# BN 1.0 1.0
# {'B': 13, 'BN': 13}
# B
# B 0.5 0.25
# BN
# BN 0.5 0.25
# p: 0.037037037037037035 1
# {'B': 1}
# B
# B 1.0 1.0
# {'B': 12, 'BN': 14}
# B
# B 0.46153846153846156 0.21301775147928997
# BN
# BN 0.5384615384615384 0.28994082840236685
# 0.020681650311279887 Is Auge_li == 35?
# p: 0.037037037037037035 1
# {'B': 1}
# B
# B 1.0 1.0
# {'B': 12, 'BN': 14}
# B
# B 0.46153846153846156 0.21301775147928997
# BN
# BN 0.5384615384615384 0.28994082840236685
# 0.020681650311279887 Is Auge_li == 28?
# p: 0.037037037037037035 1
# {'BN': 1}
# BN
# BN 1.0 1.0
# {'B': 13, 'BN': 13}
# B
# B 0.5 0.25
# BN
# BN 0.5 0.25
# p: 0.037037037037037035 1
# {'BN': 1}
# BN
# BN 1.0 1.0
# {'B': 13, 'BN': 13}
# B
# B 0.5 0.25
# BN
# BN 0.5 0.25
# p: 0.037037037037037035 1
# {'BN': 1}
# BN
# BN 1.0 1.0
# {'B': 13, 'BN': 13}
# B
# B 0.5 0.25
# BN
# BN 0.5 0.25
# p: 0.037037037037037035 1
# {'B': 1}
# B
# B 1.0 1.0
# {'B': 12, 'BN': 14}
# B
# B 0.46153846153846156 0.21301775147928997
# BN
# BN 0.5384615384615384 0.28994082840236685
# 0.020681650311279887 Is Auge_li == 16?
# p: 0.037037037037037035 1
# {'BN': 1}
# BN
# BN 1.0 1.0
# {'B': 13, 'BN': 13}
# B
# B 0.5 0.25
# BN
# BN 0.5 0.25
# p: 0.037037037037037035 1
# {'B': 1}
# B
# B 1.0 1.0
# {'B': 12, 'BN': 14}
# B
# B 0.46153846153846156 0.21301775147928997
# BN
# BN 0.5384615384615384 0.28994082840236685
# 0.020681650311279887 Is Auge_li == 5?
# p: 0.037037037037037035 1
# {'BN': 1}
# BN
# BN 1.0 1.0
# {'B': 13, 'BN': 13}
# B
# B 0.5 0.25
# BN
# BN 0.5 0.25
# p: 0.037037037037037035 1
# {'BN': 1}
# BN
# BN 1.0 1.0
# {'B': 13, 'BN': 13}
# B
# B 0.5 0.25
# BN
# BN 0.5 0.25
# p: 0.037037037037037035 1
# {'BN': 1}
# BN
# BN 1.0 1.0
# {'B': 13, 'BN': 13}
# B
# B 0.5 0.25
# BN
# BN 0.5 0.25
# p: 0.037037037037037035 1
# {'BN': 1}
# BN
# BN 1.0 1.0
# {'B': 13, 'BN': 13}
# B
# B 0.5 0.25
# BN
# BN 0.5 0.25
# p: 0.037037037037037035 1
# {'B': 1}
# B
# B 1.0 1.0
# {'B': 12, 'BN': 14}
# B
# B 0.46153846153846156 0.21301775147928997
# BN
# BN 0.5384615384615384 0.28994082840236685
# 0.020681650311279887 Is Auge_li == 14?
# p: 0.037037037037037035 1
# {'BN': 1}
# BN
# BN 1.0 1.0
# {'B': 13, 'BN': 13}
# B
# B 0.5 0.25
# BN
# BN 0.5 0.25
# p: 0.037037037037037035 1
# {'B': 1}
# B
# B 1.0 1.0
# {'B': 12, 'BN': 14}
# B
# B 0.46153846153846156 0.21301775147928997
# BN
# BN 0.5384615384615384 0.28994082840236685
# 0.020681650311279887 Is Auge_li == 15?
# p: 0.037037037037037035 1
# {'B': 1}
# B
# B 1.0 1.0
# {'B': 12, 'BN': 14}
# B
# B 0.46153846153846156 0.21301775147928997
# BN
# BN 0.5384615384615384 0.28994082840236685
# 0.020681650311279887 Is Auge_li == 36?
# p: 0.037037037037037035 1
# {'B': 1}
# B
# B 1.0 1.0
# {'B': 12, 'BN': 14}
# B
# B 0.46153846153846156 0.21301775147928997
# BN
# BN 0.5384615384615384 0.28994082840236685
# 0.020681650311279887 Is Auge_li == 2?
# p: 0.2222222222222222 6
# {'BN': 4, 'B': 2}
# BN
# BN 0.6666666666666666 0.4444444444444444
# B
# B 0.3333333333333333 0.1111111111111111
# {'B': 11, 'BN': 10}
# B
# B 0.5238095238095238 0.2743764172335601
# BN
# BN 0.47619047619047616 0.22675736961451246
# p: 0.25925925925925924 7
# {'BN': 5, 'B': 2}
# BN
# BN 0.7142857142857143 0.5102040816326531
# B
# B 0.2857142857142857 0.08163265306122448
# {'B': 11, 'BN': 9}
# B
# B 0.55 0.30250000000000005
# BN
# BN 0.45 0.2025
# 0.02682735645698614 Is Auge_re == zu?
# p: 0.5185185185185185 14
# {'B': 9, 'BN': 5}
# B
# B 0.6428571428571429 0.41326530612244905
# BN
# BN 0.35714285714285715 0.12755102040816327
# {'BN': 9, 'B': 4}
# BN
# BN 0.6923076923076923 0.4792899408284023
# B
# B 0.3076923076923077 0.09467455621301776
# 0.05609068572031545 Is Auge_re == offen?
# p: 0.2222222222222222 6
# {'BN': 4, 'B': 2}
# BN
# BN 0.6666666666666666 0.4444444444444444
# B
# B 0.3333333333333333 0.1111111111111111
# {'B': 11, 'BN': 10}
# B
# B 0.5238095238095238 0.2743764172335601
# BN
# BN 0.47619047619047616 0.22675736961451246
# p: 0.48148148148148145 13
# {'B': 5, 'BN': 8}
# B
# B 0.38461538461538464 0.14792899408284024
# BN
# BN 0.6153846153846154 0.37869822485207105
# {'B': 8, 'BN': 6}
# B
# B 0.5714285714285714 0.32653061224489793
# BN
# BN 0.42857142857142855 0.18367346938775508
# p: 0.2962962962962963 8
# {'B': 6, 'BN': 2}
# B
# B 0.75 0.5625
# BN
# BN 0.25 0.0625
# {'B': 7, 'BN': 12}
# B
# B 0.3684210526315789 0.13573407202216065
# BN
# BN 0.631578947368421 0.39889196675900274
# 0.060717637715688444 Is Mund == offen?
# p: 0.2222222222222222 6
# {'B': 1, 'BN': 5}
# B
# B 0.16666666666666666 0.027777777777777776
# BN
# BN 0.8333333333333334 0.6944444444444445
# {'B': 12, 'BN': 9}
# B
# B 0.5714285714285714 0.32653061224489793
# BN
# BN 0.42857142857142855 0.18367346938775508
# p: 0.2222222222222222 6
# {'B': 2, 'BN': 4}
# B
# B 0.3333333333333333 0.1111111111111111
# BN
# BN 0.6666666666666666 0.4444444444444444
# {'B': 11, 'BN': 10}
# B
# B 0.5238095238095238 0.2743764172335601
# BN
# BN 0.47619047619047616 0.22675736961451246
# p: 0.18518518518518517 5
# {'B': 2, 'BN': 3}
# B
# B 0.4 0.16000000000000003
# BN
# BN 0.6 0.36
# {'B': 11, 'BN': 11}
# B
# B 0.5 0.25
# BN
# BN 0.5 0.25
# p: 0.14814814814814814 4
# {'B': 2, 'BN': 2}
# B
# B 0.5 0.25
# BN
# BN 0.5 0.25
# {'B': 11, 'BN': 12}
# B
# B 0.4782608695652174 0.2287334593572779
# BN
# BN 0.5217391304347826 0.2722117202268431
# p: 0.2222222222222222 6
# {'B': 6}
# B
# B 1.0 1.0
# {'B': 7, 'BN': 14}
# B
# B 0.3333333333333333 0.1111111111111111
# BN
# BN 0.6666666666666666 0.4444444444444444
# 0.1536351165980796 Is Ass == weit offen?
# p: 0.07407407407407407 2
# {'BN': 1, 'B': 1}
# BN
# BN 0.5 0.25
# B
# B 0.5 0.25
# {'B': 12, 'BN': 13}
# B
# B 0.48 0.2304
# BN
# BN 0.52 0.27040000000000003
# p: 0.6296296296296297 17
# {'B': 11, 'BN': 6}
# B
# B 0.6470588235294118 0.41868512110726647
# BN
# BN 0.35294117647058826 0.12456747404844293
# {'BN': 8, 'B': 2}
# BN
# BN 0.8 0.6400000000000001
# B
# B 0.2 0.04000000000000001
# p: 0.07407407407407407 2
# {'BN': 2}
# BN
# BN 1.0 1.0
# {'B': 13, 'BN': 12}
# B
# B 0.52 0.27040000000000003
# BN
# BN 0.48 0.2304
# p: 0.18518518518518517 5
# {'BN': 4, 'B': 1}
# BN
# BN 0.8 0.6400000000000001
# B
# B 0.2 0.04000000000000001
# {'B': 12, 'BN': 10}
# B
# B 0.5454545454545454 0.29752066115702475
# BN
# BN 0.45454545454545453 0.20661157024793386
# p: 0.037037037037037035 1
# {'BN': 1}
# BN
# BN 1.0 1.0
# {'B': 13, 'BN': 13}
# B
# B 0.5 0.25
# BN
# BN 0.5 0.25
# {'B': 6}
# B
# B 1.0 1.0
# p: 0.16666666666666666 1
# {'B': 1}
# B
# B 1.0 1.0
# {'B': 5}
# B
# B 1.0 1.0
# 0.0 Is Auge_li == 33?
# p: 0.16666666666666666 1
# {'B': 1}
# B
# B 1.0 1.0
# {'B': 5}
# B
# B 1.0 1.0
# 0.0 Is Auge_li == 16?
# p: 0.16666666666666666 1
# {'B': 1}
# B
# B 1.0 1.0
# {'B': 5}
# B
# B 1.0 1.0
# 0.0 Is Auge_li == 35?
# p: 0.16666666666666666 1
# {'B': 1}
# B
# B 1.0 1.0
# {'B': 5}
# B
# B 1.0 1.0
# 0.0 Is Auge_li == 15?
# p: 0.16666666666666666 1
# {'B': 1}
# B
# B 1.0 1.0
# {'B': 5}
# B
# B 1.0 1.0
# 0.0 Is Auge_li == 36?
# p: 0.16666666666666666 1
# {'B': 1}
# B
# B 1.0 1.0
# {'B': 5}
# B
# B 1.0 1.0
# 0.0 Is Auge_li == 14?
# p: 0.3333333333333333 2
# {'B': 2}
# B
# B 1.0 1.0
# {'B': 4}
# B
# B 1.0 1.0
# 0.0 Is Auge_re == x?
# p: 0.3333333333333333 2
# {'B': 2}
# B
# B 1.0 1.0
# {'B': 4}
# B
# B 1.0 1.0
# 0.0 Is Auge_re == zu?
# p: 0.3333333333333333 2
# {'B': 2}
# B
# B 1.0 1.0
# {'B': 4}
# B
# B 1.0 1.0
# 0.0 Is Auge_re == offen?
# p: 0.3333333333333333 2
# {'B': 2}
# B
# B 1.0 1.0
# {'B': 4}
# B
# B 1.0 1.0
# 0.0 Is Mund == x?
# p: 0.5 3
# {'B': 3}
# B
# B 1.0 1.0
# {'B': 3}
# B
# B 1.0 1.0
# 0.0 Is Mund == zu?
# p: 0.16666666666666666 1
# {'B': 1}
# B
# B 1.0 1.0
# {'B': 5}
# B
# B 1.0 1.0
# 0.0 Is Mund == offen?
# p: 0.6666666666666666 4
# {'B': 4}
# B
# B 1.0 1.0
# {'B': 2}
# B
# B 1.0 1.0
# 0.0 Is Beschriftung == keins?
# p: 0.16666666666666666 1
# {'B': 1}
# B
# B 1.0 1.0
# {'B': 5}
# B
# B 1.0 1.0
# 0.0 Is Beschriftung == Haarschleife?
# p: 0.16666666666666666 1
# {'B': 1}
# B
# B 1.0 1.0
# {'B': 5}
# B
# B 1.0 1.0
# 0.0 Is Beschriftung == Brille?
# {'B': 7, 'BN': 14}
# B
# B 0.3333333333333333 0.1111111111111111
# BN
# BN 0.6666666666666666 0.4444444444444444
# p: 0.047619047619047616 1
# {'BN': 1}
# BN
# BN 1.0 1.0
# {'B': 7, 'BN': 13}
# B
# B 0.35 0.12249999999999998
# BN
# BN 0.65 0.42250000000000004
# 0.011111111111111072 Is Auge_li == 12?
# p: 0.047619047619047616 1
# {'BN': 1}
# BN
# BN 1.0 1.0
# {'B': 7, 'BN': 13}
# B
# B 0.35 0.12249999999999998
# BN
# BN 0.65 0.42250000000000004
# 0.011111111111111072 Is Auge_li == 25?
# p: 0.047619047619047616 1
# {'B': 1}
# B
# B 1.0 1.0
# {'B': 6, 'BN': 14}
# B
# B 0.3 0.09
# BN
# BN 0.7 0.48999999999999994
# 0.04444444444444434 Is Auge_li == 9?
# p: 0.047619047619047616 1
# {'BN': 1}
# BN
# BN 1.0 1.0
# {'B': 7, 'BN': 13}
# B
# B 0.35 0.12249999999999998
# BN
# BN 0.65 0.42250000000000004
# p: 0.047619047619047616 1
# {'B': 1}
# B
# B 1.0 1.0
# {'B': 6, 'BN': 14}
# B
# B 0.3 0.09
# BN
# BN 0.7 0.48999999999999994
# 0.04444444444444434 Is Auge_li == 1?
# p: 0.047619047619047616 1
# {'B': 1}
# B
# B 1.0 1.0
# {'B': 6, 'BN': 14}
# B
# B 0.3 0.09
# BN
# BN 0.7 0.48999999999999994
# 0.04444444444444434 Is Auge_li == 10?
# p: 0.047619047619047616 1
# {'B': 1}
# B
# B 1.0 1.0
# {'B': 6, 'BN': 14}
# B
# B 0.3 0.09
# BN
# BN 0.7 0.48999999999999994
# 0.04444444444444434 Is Auge_li == 17?
# p: 0.047619047619047616 1
# {'BN': 1}
# BN
# BN 1.0 1.0
# {'B': 7, 'BN': 13}
# B
# B 0.35 0.12249999999999998
# BN
# BN 0.65 0.42250000000000004
# p: 0.047619047619047616 1
# {'B': 1}
# B
# B 1.0 1.0
# {'B': 6, 'BN': 14}
# B
# B 0.3 0.09
# BN
# BN 0.7 0.48999999999999994
# 0.04444444444444434 Is Auge_li == 28?
# p: 0.047619047619047616 1
# {'BN': 1}
# BN
# BN 1.0 1.0
# {'B': 7, 'BN': 13}
# B
# B 0.35 0.12249999999999998
# BN
# BN 0.65 0.42250000000000004
# p: 0.047619047619047616 1
# {'BN': 1}
# BN
# BN 1.0 1.0
# {'B': 7, 'BN': 13}
# B
# B 0.35 0.12249999999999998
# BN
# BN 0.65 0.42250000000000004
# p: 0.047619047619047616 1
# {'BN': 1}
# BN
# BN 1.0 1.0
# {'B': 7, 'BN': 13}
# B
# B 0.35 0.12249999999999998
# BN
# BN 0.65 0.42250000000000004
# p: 0.047619047619047616 1
# {'BN': 1}
# BN
# BN 1.0 1.0
# {'B': 7, 'BN': 13}
# B
# B 0.35 0.12249999999999998
# BN
# BN 0.65 0.42250000000000004
# p: 0.047619047619047616 1
# {'B': 1}
# B
# B 1.0 1.0
# {'B': 6, 'BN': 14}
# B
# B 0.3 0.09
# BN
# BN 0.7 0.48999999999999994
# 0.04444444444444434 Is Auge_li == 5?
# p: 0.047619047619047616 1
# {'BN': 1}
# BN
# BN 1.0 1.0
# {'B': 7, 'BN': 13}
# B
# B 0.35 0.12249999999999998
# BN
# BN 0.65 0.42250000000000004
# p: 0.047619047619047616 1
# {'BN': 1}
# BN
# BN 1.0 1.0
# {'B': 7, 'BN': 13}
# B
# B 0.35 0.12249999999999998
# BN
# BN 0.65 0.42250000000000004
# p: 0.047619047619047616 1
# {'BN': 1}
# BN
# BN 1.0 1.0
# {'B': 7, 'BN': 13}
# B
# B 0.35 0.12249999999999998
# BN
# BN 0.65 0.42250000000000004
# p: 0.047619047619047616 1
# {'BN': 1}
# BN
# BN 1.0 1.0
# {'B': 7, 'BN': 13}
# B
# B 0.35 0.12249999999999998
# BN
# BN 0.65 0.42250000000000004
# p: 0.047619047619047616 1
# {'BN': 1}
# BN
# BN 1.0 1.0
# {'B': 7, 'BN': 13}
# B
# B 0.35 0.12249999999999998
# BN
# BN 0.65 0.42250000000000004
# p: 0.047619047619047616 1
# {'BN': 1}
# BN
# BN 1.0 1.0
# {'B': 7, 'BN': 13}
# B
# B 0.35 0.12249999999999998
# BN
# BN 0.65 0.42250000000000004
# p: 0.047619047619047616 1
# {'B': 1}
# B
# B 1.0 1.0
# {'B': 6, 'BN': 14}
# B
# B 0.3 0.09
# BN
# BN 0.7 0.48999999999999994
# 0.04444444444444434 Is Auge_li == 2?
# p: 0.19047619047619047 4
# {'BN': 4}
# BN
# BN 1.0 1.0
# {'B': 7, 'BN': 10}
# B
# B 0.4117647058823529 0.1695501730103806
# BN
# BN 0.5882352941176471 0.34602076124567477
# 0.05228758169934633 Is Auge_re == x?
# p: 0.23809523809523808 5
# {'BN': 5}
# BN
# BN 1.0 1.0
# {'B': 7, 'BN': 9}
# B
# B 0.4375 0.19140625
# BN
# BN 0.5625 0.31640625
# 0.06944444444444442 Is Auge_re == zu?
# p: 0.5714285714285714 12
# {'B': 7, 'BN': 5}
# B
# B 0.5833333333333334 0.34027777777777785
# BN
# BN 0.4166666666666667 0.17361111111111113
# {'BN': 9}
# BN
# BN 1.0 1.0
# 0.16666666666666674 Is Auge_re == offen?
# p: 0.19047619047619047 4
# {'BN': 4}
# BN
# BN 1.0 1.0
# {'B': 7, 'BN': 10}
# B
# B 0.4117647058823529 0.1695501730103806
# BN
# BN 0.5882352941176471 0.34602076124567477
# p: 0.47619047619047616 10
# {'B': 2, 'BN': 8}
# B
# B 0.2 0.04000000000000001
# BN
# BN 0.8 0.6400000000000001
# {'B': 5, 'BN': 6}
# B
# B 0.45454545454545453 0.20661157024793386
# BN
# BN 0.5454545454545454 0.29752066115702475
# p: 0.3333333333333333 7
# {'B': 5, 'BN': 2}
# B
# B 0.7142857142857143 0.5102040816326531
# BN
# BN 0.2857142857142857 0.08163265306122448
# {'B': 2, 'BN': 12}
# B
# B 0.14285714285714285 0.02040816326530612
# BN
# BN 0.8571428571428571 0.7346938775510203
# p: 0.2857142857142857 6
# {'B': 2, 'BN': 4}
# B
# B 0.3333333333333333 0.1111111111111111
# BN
# BN 0.6666666666666666 0.4444444444444444
# {'B': 5, 'BN': 10}
# B
# B 0.3333333333333333 0.1111111111111111
# BN
# BN 0.6666666666666666 0.4444444444444444
# p: 0.23809523809523808 5
# {'B': 2, 'BN': 3}
# B
# B 0.4 0.16000000000000003
# BN
# BN 0.6 0.36
# {'B': 5, 'BN': 11}
# B
# B 0.3125 0.09765625
# BN
# BN 0.6875 0.47265625
# p: 0.2857142857142857 6
# {'B': 1, 'BN': 5}
# B
# B 0.16666666666666666 0.027777777777777776
# BN
# BN 0.8333333333333334 0.6944444444444445
# {'B': 6, 'BN': 9}
# B
# B 0.4 0.16000000000000003
# BN
# BN 0.6 0.36
# p: 0.19047619047619047 4
# {'B': 2, 'BN': 2}
# B
# B 0.5 0.25
# BN
# BN 0.5 0.25
# {'B': 5, 'BN': 12}
# B
# B 0.29411764705882354 0.08650519031141869
# BN
# BN 0.7058823529411765 0.4982698961937717
# p: 0.047619047619047616 1
# {'BN': 1}
# BN
# BN 1.0 1.0
# {'B': 7, 'BN': 13}
# B
# B 0.35 0.12249999999999998
# BN
# BN 0.65 0.42250000000000004
# p: 0.6190476190476191 13
# {'B': 7, 'BN': 6}
# B
# B 0.5384615384615384 0.28994082840236685
# BN
# BN 0.46153846153846156 0.21301775147928997
# {'BN': 8}
# BN
# BN 1.0 1.0
# p: 0.09523809523809523 2
# {'BN': 2}
# BN
# BN 1.0 1.0
# {'B': 7, 'BN': 12}
# B
# B 0.3684210526315789 0.13573407202216065
# BN
# BN 0.631578947368421 0.39889196675900274
# p: 0.19047619047619047 4
# {'BN': 4}
# BN
# BN 1.0 1.0
# {'B': 7, 'BN': 10}
# B
# B 0.4117647058823529 0.1695501730103806
# BN
# BN 0.5882352941176471 0.34602076124567477
# p: 0.047619047619047616 1
# {'BN': 1}
# BN
# BN 1.0 1.0
# {'B': 7, 'BN': 13}
# B
# B 0.35 0.12249999999999998
# BN
# BN 0.65 0.42250000000000004
# {'B': 7, 'BN': 5}
# B
# B 0.5833333333333334 0.34027777777777785
# BN
# BN 0.4166666666666667 0.17361111111111113
# p: 0.08333333333333333 1
# {'B': 1}
# B
# B 1.0 1.0
# {'B': 6, 'BN': 5}
# B
# B 0.5454545454545454 0.29752066115702475
# BN
# BN 0.45454545454545453 0.20661157024793386
# 0.0315656565656563 Is Auge_li == 1?
# p: 0.08333333333333333 1
# {'BN': 1}
# BN
# BN 1.0 1.0
# {'B': 7, 'BN': 4}
# B
# B 0.6363636363636364 0.4049586776859504
# BN
# BN 0.36363636363636365 0.1322314049586777
# 0.061868686868686684 Is Auge_li == 25?
# p: 0.08333333333333333 1
# {'B': 1}
# B
# B 1.0 1.0
# {'B': 6, 'BN': 5}
# B
# B 0.5454545454545454 0.29752066115702475
# BN
# BN 0.45454545454545453 0.20661157024793386
# p: 0.08333333333333333 1
# {'B': 1}
# B
# B 1.0 1.0
# {'B': 6, 'BN': 5}
# B
# B 0.5454545454545454 0.29752066115702475
# BN
# BN 0.45454545454545453 0.20661157024793386
# p: 0.08333333333333333 1
# {'B': 1}
# B
# B 1.0 1.0
# {'B': 6, 'BN': 5}
# B
# B 0.5454545454545454 0.29752066115702475
# BN
# BN 0.45454545454545453 0.20661157024793386
# p: 0.08333333333333333 1
# {'BN': 1}
# BN
# BN 1.0 1.0
# {'B': 7, 'BN': 4}
# B
# B 0.6363636363636364 0.4049586776859504
# BN
# BN 0.36363636363636365 0.1322314049586777
# 0.061868686868686684 Is Auge_li == 22?
# p: 0.08333333333333333 1
# {'B': 1}
# B
# B 1.0 1.0
# {'B': 6, 'BN': 5}
# B
# B 0.5454545454545454 0.29752066115702475
# BN
# BN 0.45454545454545453 0.20661157024793386
# p: 0.08333333333333333 1
# {'B': 1}
# B
# B 1.0 1.0
# {'B': 6, 'BN': 5}
# B
# B 0.5454545454545454 0.29752066115702475
# BN
# BN 0.45454545454545453 0.20661157024793386
# p: 0.08333333333333333 1
# {'BN': 1}
# BN
# BN 1.0 1.0
# {'B': 7, 'BN': 4}
# B
# B 0.6363636363636364 0.4049586776859504
# BN
# BN 0.36363636363636365 0.1322314049586777
# 0.061868686868686684 Is Auge_li == 30?
# p: 0.08333333333333333 1
# {'BN': 1}
# BN
# BN 1.0 1.0
# {'B': 7, 'BN': 4}
# B
# B 0.6363636363636364 0.4049586776859504
# BN
# BN 0.36363636363636365 0.1322314049586777
# 0.061868686868686684 Is Auge_li == 37?
# p: 0.08333333333333333 1
# {'BN': 1}
# BN
# BN 1.0 1.0
# {'B': 7, 'BN': 4}
# B
# B 0.6363636363636364 0.4049586776859504
# BN
# BN 0.36363636363636365 0.1322314049586777
# 0.061868686868686684 Is Auge_li == 38?
# p: 0.08333333333333333 1
# {'B': 1}
# B
# B 1.0 1.0
# {'B': 6, 'BN': 5}
# B
# B 0.5454545454545454 0.29752066115702475
# BN
# BN 0.45454545454545453 0.20661157024793386
# p: 0.4166666666666667 5
# {'B': 2, 'BN': 3}
# B
# B 0.4 0.16000000000000003
# BN
# BN 0.6 0.36
# {'B': 5, 'BN': 2}
# B
# B 0.7142857142857143 0.5102040816326531
# BN
# BN 0.2857142857142857 0.08163265306122448
# p: 0.5833333333333334 7
# {'B': 5, 'BN': 2}
# B
# B 0.7142857142857143 0.5102040816326531
# BN
# BN 0.2857142857142857 0.08163265306122448
# {'B': 2, 'BN': 3}
# B
# B 0.4 0.16000000000000003
# BN
# BN 0.6 0.36
# p: 0.25 3
# {'B': 2, 'BN': 1}
# B
# B 0.6666666666666666 0.4444444444444444
# BN
# BN 0.3333333333333333 0.1111111111111111
# {'B': 5, 'BN': 4}
# B
# B 0.5555555555555556 0.308641975308642
# BN
# BN 0.4444444444444444 0.19753086419753085
# p: 0.25 3
# {'B': 2, 'BN': 1}
# B
# B 0.6666666666666666 0.4444444444444444
# BN
# BN 0.3333333333333333 0.1111111111111111
# {'B': 5, 'BN': 4}
# B
# B 0.5555555555555556 0.308641975308642
# BN
# BN 0.4444444444444444 0.19753086419753085
# p: 0.25 3
# {'B': 1, 'BN': 2}
# B
# B 0.3333333333333333 0.1111111111111111
# BN
# BN 0.6666666666666666 0.4444444444444444
# {'B': 6, 'BN': 3}
# B
# B 0.6666666666666666 0.4444444444444444
# BN
# BN 0.3333333333333333 0.1111111111111111
# p: 0.25 3
# {'B': 2, 'BN': 1}
# B
# B 0.6666666666666666 0.4444444444444444
# BN
# BN 0.3333333333333333 0.1111111111111111
# {'B': 5, 'BN': 4}
# B
# B 0.5555555555555556 0.308641975308642
# BN
# BN 0.4444444444444444 0.19753086419753085
# p: 0.5833333333333334 7
# {'B': 7}
# B
# B 1.0 1.0
# {'BN': 5}
# BN
# BN 1.0 1.0
# 0.48611111111111094 Is Beschriftung == keins?
# p: 0.08333333333333333 1
# {'BN': 1}
# BN
# BN 1.0 1.0
# {'B': 7, 'BN': 4}
# B
# B 0.6363636363636364 0.4049586776859504
# BN
# BN 0.36363636363636365 0.1322314049586777
# p: 0.25 3
# {'BN': 3}
# BN
# BN 1.0 1.0
# {'B': 7, 'BN': 2}
# B
# B 0.7777777777777778 0.6049382716049383
# BN
# BN 0.2222222222222222 0.04938271604938271
# p: 0.08333333333333333 1
# {'BN': 1}
# BN
# BN 1.0 1.0
# {'B': 7, 'BN': 4}
# B
# B 0.6363636363636364 0.4049586776859504
# BN
# BN 0.36363636363636365 0.1322314049586777
# {'B': 7}
# B
# B 1.0 1.0
# p: 0.14285714285714285 1
# {'B': 1}
# B
# B 1.0 1.0
# {'B': 6}
# B
# B 1.0 1.0
# 0.0 Is Auge_li == 1?
# p: 0.14285714285714285 1
# {'B': 1}
# B
# B 1.0 1.0
# {'B': 6}
# B
# B 1.0 1.0
# 0.0 Is Auge_li == 9?
# p: 0.14285714285714285 1
# {'B': 1}
# B
# B 1.0 1.0
# {'B': 6}
# B
# B 1.0 1.0
# 0.0 Is Auge_li == 10?
# p: 0.14285714285714285 1
# {'B': 1}
# B
# B 1.0 1.0
# {'B': 6}
# B
# B 1.0 1.0
# 0.0 Is Auge_li == 17?
# p: 0.14285714285714285 1
# {'B': 1}
# B
# B 1.0 1.0
# {'B': 6}
# B
# B 1.0 1.0
# 0.0 Is Auge_li == 28?
# p: 0.14285714285714285 1
# {'B': 1}
# B
# B 1.0 1.0
# {'B': 6}
# B
# B 1.0 1.0
# 0.0 Is Auge_li == 5?
# p: 0.14285714285714285 1
# {'B': 1}
# B
# B 1.0 1.0
# {'B': 6}
# B
# B 1.0 1.0
# 0.0 Is Auge_li == 2?
# p: 0.2857142857142857 2
# {'B': 2}
# B
# B 1.0 1.0
# {'B': 5}
# B
# B 1.0 1.0
# 0.0 Is Mund == zu?
# p: 0.7142857142857143 5
# {'B': 5}
# B
# B 1.0 1.0
# {'B': 2}
# B
# B 1.0 1.0
# 0.0 Is Mund == offen?
# p: 0.2857142857142857 2
# {'B': 2}
# B
# B 1.0 1.0
# {'B': 5}
# B
# B 1.0 1.0
# 0.0 Is Ass == Zahn?
# p: 0.2857142857142857 2
# {'B': 2}
# B
# B 1.0 1.0
# {'B': 5}
# B
# B 1.0 1.0
# 0.0 Is Ass == grimmig?
# p: 0.14285714285714285 1
# {'B': 1}
# B
# B 1.0 1.0
# {'B': 6}
# B
# B 1.0 1.0
# 0.0 Is Ass == Zunge?
# p: 0.2857142857142857 2
# {'B': 2}
# B
# B 1.0 1.0
# {'B': 5}
# B
# B 1.0 1.0
# 0.0 Is Ass == Grinsen?
# {'BN': 5}
# BN
# BN 1.0 1.0
# p: 0.2 1
# {'BN': 1}
# BN
# BN 1.0 1.0
# {'BN': 4}
# BN
# BN 1.0 1.0
# 0.0 Is Auge_li == 25?
# p: 0.2 1
# {'BN': 1}
# BN
# BN 1.0 1.0
# {'BN': 4}
# BN
# BN 1.0 1.0
# 0.0 Is Auge_li == 22?
# p: 0.2 1
# {'BN': 1}
# BN
# BN 1.0 1.0
# {'BN': 4}
# BN
# BN 1.0 1.0
# 0.0 Is Auge_li == 30?
# p: 0.2 1
# {'BN': 1}
# BN
# BN 1.0 1.0
# {'BN': 4}
# BN
# BN 1.0 1.0
# 0.0 Is Auge_li == 37?
# p: 0.2 1
# {'BN': 1}
# BN
# BN 1.0 1.0
# {'BN': 4}
# BN
# BN 1.0 1.0
# 0.0 Is Auge_li == 38?
# p: 0.6 3
# {'BN': 3}
# BN
# BN 1.0 1.0
# {'BN': 2}
# BN
# BN 1.0 1.0
# 0.0 Is Mund == zu?
# p: 0.4 2
# {'BN': 2}
# BN
# BN 1.0 1.0
# {'BN': 3}
# BN
# BN 1.0 1.0
# 0.0 Is Mund == offen?
# p: 0.2 1
# {'BN': 1}
# BN
# BN 1.0 1.0
# {'BN': 4}
# BN
# BN 1.0 1.0
# 0.0 Is Ass == Zahn?
# p: 0.2 1
# {'BN': 1}
# BN
# BN 1.0 1.0
# {'BN': 4}
# BN
# BN 1.0 1.0
# 0.0 Is Ass == grimmig?
# p: 0.4 2
# {'BN': 2}
# BN
# BN 1.0 1.0
# {'BN': 3}
# BN
# BN 1.0 1.0
# 0.0 Is Ass == Zunge?
# p: 0.2 1
# {'BN': 1}
# BN
# BN 1.0 1.0
# {'BN': 4}
# BN
# BN 1.0 1.0
# 0.0 Is Ass == Grinsen?
# p: 0.2 1
# {'BN': 1}
# BN
# BN 1.0 1.0
# {'BN': 4}
# BN
# BN 1.0 1.0
# 0.0 Is Beschriftung == Haarschleife?
# p: 0.6 3
# {'BN': 3}
# BN
# BN 1.0 1.0
# {'BN': 2}
# BN
# BN 1.0 1.0
# 0.0 Is Beschriftung == Brille?
# p: 0.2 1
# {'BN': 1}
# BN
# BN 1.0 1.0
# {'BN': 4}
# BN
# BN 1.0 1.0
# 0.0 Is Beschriftung == Augenbinde?
# {'BN': 9}
# BN
# BN 1.0 1.0
# p: 0.1111111111111111 1
# {'BN': 1}
# BN
# BN 1.0 1.0
# {'BN': 8}
# BN
# BN 1.0 1.0
# 0.0 Is Auge_li == 12?
# p: 0.1111111111111111 1
# {'BN': 1}
# BN
# BN 1.0 1.0
# {'BN': 8}
# BN
# BN 1.0 1.0
# 0.0 Is Auge_li == 7?
# p: 0.1111111111111111 1
# {'BN': 1}
# BN
# BN 1.0 1.0
# {'BN': 8}
# BN
# BN 1.0 1.0
# 0.0 Is Auge_li == 4?
# p: 0.1111111111111111 1
# {'BN': 1}
# BN
# BN 1.0 1.0
# {'BN': 8}
# BN
# BN 1.0 1.0
# 0.0 Is Auge_li == 39?
# p: 0.1111111111111111 1
# {'BN': 1}
# BN
# BN 1.0 1.0
# {'BN': 8}
# BN
# BN 1.0 1.0
# 0.0 Is Auge_li == 23?
# p: 0.1111111111111111 1
# {'BN': 1}
# BN
# BN 1.0 1.0
# {'BN': 8}
# BN
# BN 1.0 1.0
# 0.0 Is Auge_li == 24?
# p: 0.1111111111111111 1
# {'BN': 1}
# BN
# BN 1.0 1.0
# {'BN': 8}
# BN
# BN 1.0 1.0
# 0.0 Is Auge_li == 40?
# p: 0.1111111111111111 1
# {'BN': 1}
# BN
# BN 1.0 1.0
# {'BN': 8}
# BN
# BN 1.0 1.0
# 0.0 Is Auge_li == 19?
# p: 0.1111111111111111 1
# {'BN': 1}
# BN
# BN 1.0 1.0
# {'BN': 8}
# BN
# BN 1.0 1.0
# 0.0 Is Auge_li == 32?
# p: 0.4444444444444444 4
# {'BN': 4}
# BN
# BN 1.0 1.0
# {'BN': 5}
# BN
# BN 1.0 1.0
# 0.0 Is Auge_re == x?
# p: 0.5555555555555556 5
# {'BN': 5}
# BN
# BN 1.0 1.0
# {'BN': 4}
# BN
# BN 1.0 1.0
# 0.0 Is Auge_re == zu?
# p: 0.4444444444444444 4
# {'BN': 4}
# BN
# BN 1.0 1.0
# {'BN': 5}
# BN
# BN 1.0 1.0
# 0.0 Is Mund == x?
# p: 0.5555555555555556 5
# {'BN': 5}
# BN
# BN 1.0 1.0
# {'BN': 4}
# BN
# BN 1.0 1.0
# 0.0 Is Mund == zu?
# p: 0.3333333333333333 3
# {'BN': 3}
# BN
# BN 1.0 1.0
# {'BN': 6}
# BN
# BN 1.0 1.0
# 0.0 Is Ass == Zahn?
# p: 0.2222222222222222 2
# {'BN': 2}
# BN
# BN 1.0 1.0
# {'BN': 7}
# BN
# BN 1.0 1.0
# 0.0 Is Ass == grimmig?
# p: 0.3333333333333333 3
# {'BN': 3}
# BN
# BN 1.0 1.0
# {'BN': 6}
# BN
# BN 1.0 1.0
# 0.0 Is Ass == Zunge?
# p: 0.1111111111111111 1
# {'BN': 1}
# BN
# BN 1.0 1.0
# {'BN': 8}
# BN
# BN 1.0 1.0
# 0.0 Is Ass == Grinsen?
# p: 0.6666666666666666 6
# {'BN': 6}
# BN
# BN 1.0 1.0
# {'BN': 3}
# BN
# BN 1.0 1.0
# 0.0 Is Beschriftung == keins?
# p: 0.1111111111111111 1
# {'BN': 1}
# BN
# BN 1.0 1.0
# {'BN': 8}
# BN
# BN 1.0 1.0
# 0.0 Is Beschriftung == Brille?
# p: 0.2222222222222222 2
# {'BN': 2}
# BN
# BN 1.0 1.0
# {'BN': 7}
# BN
# BN 1.0 1.0
# 0.0 Is Beschriftung == Pflaster_links?

# %%
print_tree(my_tree)
# Out:
# Is Ass == weit offen?
# --> True:
#   Predict {'B': 6}
# --> False:
#   Is Auge_re == offen?
#   --> True:
#     Is Beschriftung == keins?
#     --> True:
#       Predict {'B': 7}
#     --> False:
#       Predict {'BN': 5}
#   --> False:
#     Predict {'BN': 9}

# %%
def classify(row, node):
    """See the 'rules of recursion' above."""

    # Base case: we've reached a leaf
    if isinstance(node, Leaf):
        return node.predictions

    # Decide whether to follow the true-branch or the false-branch.
    # Compare the feature / value stored in the node,
    # to the example we're considering.
    if node.question.match(row):
        return classify(row, node.true_branch)
    else:
        return classify(row, node.false_branch)

# %%
#######
# Demo:
# The tree predicts the 1st row of our
# training data is an apple with confidence 1.
classify(training_data[0], my_tree)
#######
# Out:
# {'B': 7}

# %%
def print_leaf(counts):
    """A nicer way to print the predictions at a leaf."""
    total = sum(counts.values()) * 1.0
    probs = {}
    for lbl in counts.keys():
        probs[lbl] = str(int(counts[lbl] / total * 100)) + "%"
    return probs

# %%
#######
# Demo:
# Printing that a bit nicer
print_leaf(classify(training_data[0], my_tree))
#######
# Out:
# {'B': '100%'}

# %%
#######
# Demo:
# On the second example, the confidence is lower
print_leaf(classify(training_data[1], my_tree))
#######
# Out:
# {'B': '100%'}

# %%
# Evaluate
testing_data = affenTest
affenTest
# Out:
# [['x', 'x', 'Zahn', 'keins', 'BN'],
#  ['offen', 'zu', 'Grinsen', 'keins', 'B'],
#  ['zu', 'zu', 'Grinsen', 'keins', 'BN'],
#  ['x', 'x', 'grimmig', 'keins', 'BN'],
#  ['offen', 'offen', 'weit offen', 'keins', 'B'],
#  ['offen', 'zu', 'Zunge', 'keins', 'B'],
#  ['offen', 'offen', 'verschmitzt', 'Augenbinde', 'BN'],
#  ['offen', 'zu', 'Grinsen', 'Pflaster_rechts', 'BN'],
#  ['x', 'x', 'Grinsen', 'Haare', 'BN'],
#  ['offen', 'offen', 'grimmig', 'Augenbinde', 'BN'],
#  ['x', 'x', 'grimmig', 'Pflaster_links', 'BN'],
#  ['offen', 'zu', 'offen', 'Pflaster_rechts', 'B']]

# %%
for row in testing_data:
    print ("Actual: %s. Predicted: %s" %
           (row[-1], print_leaf(classify(row, my_tree))))
# Out:
# Actual: BN. Predicted: {'BN': '100%'}
# Actual: B. Predicted: {'BN': '100%'}
# Actual: BN. Predicted: {'BN': '100%'}
# Actual: BN. Predicted: {'BN': '100%'}
# Actual: B. Predicted: {'BN': '100%'}
# Actual: B. Predicted: {'BN': '100%'}
# Actual: BN. Predicted: {'BN': '100%'}
# Actual: BN. Predicted: {'BN': '100%'}
# Actual: BN. Predicted: {'BN': '100%'}
# Actual: BN. Predicted: {'BN': '100%'}
# Actual: BN. Predicted: {'BN': '100%'}
# Actual: B. Predicted: {'BN': '100%'}
