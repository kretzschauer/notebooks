# %%
import numpy as np
import random
import matplotlib.pyplot as plt
# %matplotlib inline
from K_Means_Klasse import *

# %%
puAr=np.loadtxt("iris.csv",delimiter=",",skiprows=0,usecols=(0,1,2,3))
print("Array der eingelesenen Datenpunkte:\n",puAr[:5])
nameAr=np.loadtxt("iris.csv",delimiter=",",usecols=4,dtype=str)
print("Namen: ",nameAr[:5])
# Out:
# Array der eingelesenen Datenpunkte:
#  [[5.1 3.5 1.4 0.2]
#  [4.9 3.  1.4 0.2]
#  [4.7 3.2 1.3 0.2]
#  [4.6 3.1 1.5 0.2]
#  [5.  3.6 1.4 0.2]]
# Namen:  ['Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa']

# %%
fig, axs = plt.subplots(2,3)
plt.rcParams['figure.figsize'] = (20,20)
Spalten=["Sepal.L","Sepal.W","Petal.L","Petal.W"]
ms=[(0,1),(0,2),(0,3),(1,2),(1,3),(2,3)]
ns=[(0,0),(0,1),(0,2),(1,0),(1,1),(1,2)]

for i in range(6):       
    txt= Spalten[ms[i][0]]+" - "+Spalten[ms[i][1]]
    axs[ns[i][0],ns[i][1]].set_title(txt)
    axs[ns[i][0],ns[i][1]].scatter(puAr[:50, ms[i][0]], puAr[:50, ms[i][1]],color="red")
    axs[ns[i][0],ns[i][1]].scatter(puAr[50:100, ms[i][0]], puAr[50:100, ms[i][1]],color="green")
    axs[ns[i][0],ns[i][1]].scatter(puAr[100:150, ms[i][0]], puAr[100:150, ms[i][1]],color="blue")        
    
plt.show()
