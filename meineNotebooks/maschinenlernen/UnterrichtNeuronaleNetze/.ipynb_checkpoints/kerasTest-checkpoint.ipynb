# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd# Importing the dataset
import pandas as pd
dataset = pd.read_csv('Churn_Modelling.csv')
dataset
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %% [markdown]
# # ein neuronales Netzwerk bauen und trainieren
# Quelle: https://medium.com/@pushkarmandot/build-your-first-deep-learning-neural-network-model-using-keras-in-python-a90b5864116d

# %%
X = dataset.iloc[:, 3:13].values
y = dataset.iloc[:, 13].values
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
A = make_column_transformer(
    (OneHotEncoder(categories='Geography'), [0]), 
    remainder="passthrough")

X=A.fit_transform(X)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-6afa8739a80b> in <module>
#       7     remainder="passthrough")
#       8
# ----> 9 X=A.fit_transform(X)
#
# c:\program files\python38\lib\site-packages\sklearn\compose\_column_transformer.py in fit_transform(self, X, y)
#     506         self._validate_remainder(X)
#     507
# --> 508         result = self._fit_transform(X, y, _fit_transform_one)
#     509
#     510         if not result:
#
# c:\program files\python38\lib\site-packages\sklearn\compose\_column_transformer.py in _fit_transform(self, X, y, func, fitted)
#     433             self._iter(fitted=fitted, replace_strings=True))
#     434         try:
# --> 435             return Parallel(n_jobs=self.n_jobs)(
#     436                 delayed(func)(
#     437                     transformer=clone(trans) if not fitted else trans,
#
# ...

# %%
X = dataset.iloc[:, 3:13].values
y = dataset.iloc[:, 13].values
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
ct = ColumnTransformer([("Geography", OneHotEncoder(), [0])], remainder = 'passthrough')
X = ct.fit_transform(X)
"""labelencoder_X_1 = LabelEncoder()
X[:, 1] = labelencoder_X_1.fit_transform(X[:, 1])
labelencoder_X_2 = LabelEncoder()
X[:, 2] = labelencoder_X_2.fit_transform(X[:, 2])"""
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\program files\python38\lib\site-packages\sklearn\compose\_column_transformer.py in _hstack(self, Xs)
#     588                 # dtype conversion if necessary.
# --> 589                 converted_Xs = [check_array(X,
#     590                                             accept_sparse=True,
#
# c:\program files\python38\lib\site-packages\sklearn\compose\_column_transformer.py in <listcomp>(.0)
#     588                 # dtype conversion if necessary.
# --> 589                 converted_Xs = [check_array(X,
#     590                                             accept_sparse=True,
#
# c:\program files\python38\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#
# ...

# %%
onehotencoder = OneHotEncoder(categorical_features = [1])
X = onehotencoder.fit_transform(X).toarray()
X = X[:, 1:]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-534ab12beaa3> in <module>
# ----> 1 onehotencoder = OneHotEncoder(categorical_features = [1])
#       2 X = onehotencoder.fit_transform(X).toarray()
#       3 X = X[:, 1:]
#
# c:\program files\python38\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# TypeError: __init__() got an unexpected keyword argument 'categorical_features'

# %% [markdown]
# Umwandeln der Länder in Kategorien und dann in onehot-Spalten
# https://towardsdatascience.com/categorical-encoding-using-label-encoding-and-one-hot-encoder-911ef77fb5bd
