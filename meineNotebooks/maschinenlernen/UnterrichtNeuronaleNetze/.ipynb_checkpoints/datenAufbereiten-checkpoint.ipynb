# %% [markdown]
# # Ein neuronales Netzwerk bauen und trainieren
# Quellen:
# * https://medium.com/@pushkarmandot/build-your-first-deep-learning-neural-network-model-using-keras-in-python-a90b5864116d
# * https://isolution.pro/de/t/python-deep-learning/python-deep-learning-implementations/python-deep-learning-implementierungen
# * https://markusneuschaefer.de/deep-learning-basics-neural-networks#anwendung-welche-kunden-sind-bald-weg

# %%
import pandas as pd
import numpy as np
dataset = pd.read_csv('Churn_Modelling.csv')
X = dataset.iloc[:, 3:13]#.values
y = dataset.iloc[:, 13]#.values
X = pd.get_dummies(X, columns=["Geography"], prefix=["Land_is"] )
X = pd.get_dummies(X, columns=["Gender"], prefix=["G_is"] )

# %%
X
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Land_is_France  Land_is_Germany  \
# 0                  1        101348.88               1                0
# ...

# %% [markdown]
# # Aufbereitung von Daten
# * Datensatz und Quelle: https://medium.com/@pushkarmandot/build-your-first-deep-learning-neural-network-model-using-keras-in-python-a90b5864116d
# * Einlesen der Daten
# * Umwandeln der Daten, die in Kategorien gegeben sind, in Dummy-Spalten und OneHotEncoding.
# * https://ichi.pro/de/kategoriale-codierung-mit-label-codierung-und-one-hot-encoder-159562187388349
# * Aufteilen in Trainingsdaten und Testdaten
# * Skalieren der Merkmale:
#  * MinMaxScaler: Mappt die Merkmale zwischen den angegebenen Bereich, hier 0 und 1
#  * StandardScaler: Mappt die Merkmale so, dass der Mittelwert 0 ist und die Standardabweichung 1

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)
from sklearn import preprocessing # import StandardScaler
#sc = StandardScaler() #als Alternative
sc =preprocessing.StandardScaler()#MinMaxScaler(feature_range=(0, 1))
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
X_test[0:3]
# Out:
# array([[-0.43631508, -0.56636638,  1.37824795,  0.21387074, -0.91126927,
#          0.64570298, -1.03797037, -0.54090497,  0.99750312, -0.57253893,
#         -0.58023704, -0.91324755,  0.91324755],
#        [ 1.08487046, -0.18168828, -1.72504042,  0.59597618,  0.8133946 ,
#          0.64570298,  0.96341863,  0.30633327, -1.00250313,  1.74660611,
#         -0.58023704,  1.09499335, -1.09499335],
#        [-0.7571093 ,  0.39532888, -0.69061097, -1.22472772,  0.8133946 ,
#          0.64570298,  0.96341863,  0.61325301, -1.00250313, -0.57253893,
#          1.72343359, -0.91324755,  0.91324755]])

# %% [markdown]
# ## Netzwerk bauen
# * 13 Inputs, 2 Hidden Schichten mit je 6 Neuronen und einen Output
# * Aktivierung mit relu

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
classifier = Sequential()

# %%
# Adding the input layer and the first hidden layer
classifier.add(Dense( 6, kernel_initializer = 'uniform', activation = 'relu', input_dim = 13))
# Adding the second hidden layer
classifier.add(Dense( 6, kernel_initializer = 'uniform', activation = 'relu'))
# Adding the output layer
classifier.add(Dense(1, kernel_initializer= 'uniform', activation = 'sigmoid'))

# %%
# Compiling Neural Network
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
# Fitting our model 
classifier.fit(X_train, y_train, batch_size = 10, epochs = 100)
# Out:
# Epoch 1/100
# 800/800 [==============================] - 1s 676us/step - loss: 0.5909 - accuracy: 0.7934
# Epoch 2/100
# 800/800 [==============================] - 1s 688us/step - loss: 0.4659 - accuracy: 0.7997
# Epoch 3/100
# 800/800 [==============================] - 1s 663us/step - loss: 0.4455 - accuracy: 0.8003
# Epoch 4/100
# 800/800 [==============================] - 1s 663us/step - loss: 0.4409 - accuracy: 0.7995
# Epoch 5/100
# 800/800 [==============================] - 1s 638us/step - loss: 0.4381 - accuracy: 0.7959
# Epoch 6/100
# 800/800 [==============================] - 1s 639us/step - loss: 0.4283 - accuracy: 0.8052
# Epoch 7/100
# 800/800 [==============================] - 1s 651us/step - loss: 0.4213 - accuracy: 0.8217
# Epoch 8/100
# 800/800 [==============================] - 1s 663us/step - loss: 0.4262 - accuracy: 0.8198
# Epoch 9/100
# 800/800 [==============================] - 1s 701us/step - loss: 0.4299 - accuracy: 0.8186
# Epoch 10/100
# ...

# %%
# Predicting the Test set results
y_pred = classifier.predict(X_test)
y_pred = (y_pred > 0.5)

# %%
# Creating the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

# %%
cm
# Out:
# array([[1497,   75],
#        [ 217,  211]], dtype=int64)
